# %% [markdown]
# # Importing functions into notebooks and using libraries

# %%
from ls08 import squares

# %%
print(squares(2, 10))
# Out:
# [4, 9]

# %%
import seaborn

# %%
seaborn.barplot(x=["A", "B", "C", "D"], y=[1.0, 2.0, 3.0, 4.0])
# Out:
# <AxesSubplot:>
